# %% [markdown]
# # My Jupter Notebook on IBM Watson Studio

# %% [markdown]
# Chrissy Johnson - Junior Analyst

# %% [markdown]
# _I am interested in data science because since data analyitcs has become a part of my current job, i have never enjoyed it more. I want to learn as much as i can to be the best data scientist i can be._

# %% [markdown]
# ### This code will sum two numbers

# %%
5 + 5
# Out:
# 10

# %% [markdown]
# Next lets see what we can do
# * Bullet points
# 1. Numbers
#
# [Ask Google for any questions](https://www.google.com/)
# ![face.PNG](attachment:face.PNG)
